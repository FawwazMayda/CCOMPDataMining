# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('train.csv')

# %%
df.head()
# Out:
#       A       B  C  D  E   F  G  H  I  J ...      P      Q      R     S     T  \
# 0  5770  360000  1  2  1  45  2  2 -2 -2 ...      0      0      0     0     0
# 1  5772  300000  1  2  1  40 -2 -2 -2 -2 ...   2208   2475   7580  4347     0
# 2  5773   20000  2  1  2  22 -2 -2 -2 -2 ...    304      0    302     0   913
# 3  5774  270000  2  2  2  26  0  0  0  0 ...  14391  15255  16273  1300  1533
# 4  5775   20000  2  3  2  49  0  0  0  0 ...  19334  19373  19460  1337  2000
#
#       U     V     W     X  Y
# 0     0     0     0     0  0
# 1  2208  2475  7580     0  0
# 2   304     0   302  7676  0
# 3  1391  1255  1273  1000  0
# 4   666   714   810   600  0
#
# [5 rows x 25 columns]

# %%
idx=['ID', 'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6', 'default']

# %%
df.columns=idx
df.head()
# Out:
#      ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# 0  5770     360000    1          2         1   45      2      2     -2     -2
# 1  5772     300000    1          2         1   40     -2     -2     -2     -2
# 2  5773      20000    2          1         2   22     -2     -2     -2     -2
# 3  5774     270000    2          2         2   26      0      0      0      0
# 4  5775      20000    2          3         2   49      0      0      0      0
#
#     ...     BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0   ...             0          0          0         0         0         0
# 1   ...          2208       2475       7580      4347         0      2208
# 2   ...           304          0        302         0       913       304
# 3   ...         14391      15255      16273      1300      1533      1391
# 4   ...         19334      19373      19460      1337      2000       666
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default
# ...

# %% [markdown]
# Gambarkan Plot

# %%
pd.crosstab(df['SEX'],df.default).plot(kind='bar')
plt.title('Pengaruh jenis kelamin dengan default nasabah')
plt.ylabel('COUNT')
plt.savefig('Get Foto/1.png')
plt.show()

# %%
pd.crosstab(df['EDUCATION'],df.default).plot(kind='bar')
plt.title('Pengaruh pendidikan dengan default nasabah')
plt.ylabel('COUNT')
plt.savefig('Get Foto/2.png')
plt.show()

# %%
pd.crosstab(df['MARRIAGE'],df.default).plot(kind='bar')
plt.title('Pengaruh status nikah dengan default nasabah')
plt.ylabel('COUNT')
plt.savefig('Get Foto/3.png')
plt.show()

# %%
pd.crosstab(df.AGE,df.default).plot(kind='bar')
plt.title('Pengaruh umur dengan default nasabah')
plt.xlabel('Umur')
plt.xscale('linear')
plt.savefig('Get Foto/4.png')
plt.show()

# %%
for i in range(1,7):
    st='PAY_' + str(i)
    pd.crosstab(df[st],df.default).plot(kind='bar')
    plt.title('Pengaruh '+st+' terhadap default nasabah')
    plt.ylabel('COUNT')
    plt.savefig("Get Foto/PAY/"+str(i)+".png")

# %% [markdown]
# Numeric col only

# %%
n_col=[]
for i in range(1,7):
    st='PAY_'+str(i)
    n_col.append(st)
for i in range(1,7):
    st='BILL_AMT'+str(i)
    n_col.append(st)
for i in range(1,7):
    st='PAY_AMT'+str(i)
    n_col.append(st)
print(n_col)
# Out:
# ['PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 'BILL_AMT1', 'BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6', 'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# %%
df_n=df.loc[:,n_col]
df_n['default']=df.default
df_n.head()
# Out:
#    PAY_1  PAY_2  PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  \
# 0      2      2     -2     -2     -2     -2       2500          0          0
# 1     -2     -2     -2     -2     -2     -2      15876       4347          0
# 2     -2     -2     -2     -2     -2     -1         -9         -9        904
# 3      0      0      0      0      0      0      29951      12211      13533
# 4      0      0      0      0      0      0      19437      20154      18957
#
#    BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  \
# 0          0          0          0         0         0         0         0
# 1       2208       2475       7580      4347         0      2208      2475
# 2        304          0        302         0       913       304         0
# 3      14391      15255      16273      1300      1533      1391      1255
# 4      19334      19373      19460      1337      2000       666       714
#
#    PAY_AMT5  PAY_AMT6  default
# ...

# %%
import seaborn as sns

# %%
dfc=df_n.corr()
plt.figure(figsize=(32,32))
sns.heatmap(dfc,annot=True)
plt.show()

# %%
dfc=df.corr()
plt.figure(figsize=(32,32))
sns.heatmap(dfc,annot=True)
plt.show()

# %%
for i in range(1,7):
    st='BILL_AMT' + str(i)
    plt.scatter(x=df[st],y=df.default)
    plt.title('Pengaruh '+st+' terhadap default nasabah')
    plt.ylabel('COUNT')
    plt.savefig("Get Foto/BILL AMT/"+str(i)+".png")
    plt.clf()

# %%
for i in range(1,7):
    st='PAY_AMT' + str(i)
    plt.scatter(x=df[st],y=df.default)
    plt.title('Pengaruh '+st+' terhadap default nasabah')
    plt.ylabel('COUNT')
    plt.savefig("Get Foto/PAY AMT/"+str(i)+".png")
    plt.clf()

# %%
plt.scatter(x=df['LIMIT_BAL'],y=df.default)
plt.title('Pengaruh LIMIT_BAL terhadap default nasabah')
plt.xlabel('LIMIT_BAL')
plt.ylabel('default')
plt.savefig('Get Foto/5.png')
plt.show()

# %%
to_keep=['LIMIT_BAL','SEX','EDUCATION','MARRIAGE','AGE','PAY_1','PAY_2','PAY_6','BILL_AMT1']
X=df.loc[:,to_keep]
Y=df.loc[:,'default']
print(X.shape)
print(Y.shape)
print(X.head())
print(Y.head())
# Out:
# (21000, 9)
# (21000,)
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_6  BILL_AMT1
# 0     360000    1          2         1   45      2      2     -2       2500
# 1     300000    1          2         1   40     -2     -2     -2      15876
# 2      20000    2          1         2   22     -2     -2     -1         -9
# 3     270000    2          2         2   26      0      0      0      29951
# 4      20000    2          3         2   49      0      0      0      19437
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: default, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(X,Y,test_size=0.2,random_state=21)

# %%
mss=[]
msl=[]
md=[]
mln=[]
scores=[]
for minsamplesplit in range(2,5):
    for minsampleleaf in range(2,5):
        for maxdepth in range(15,19):
            for maxleafnodes in range(15,19):
                dt=DecisionTreeClassifier(max_depth =maxdepth ,
                                          min_samples_split = minsamplesplit, 
                                          min_samples_leaf=minsampleleaf
                                          , max_leaf_nodes = maxleafnodes)
                dt.fit(x_train,y_train)
                score=dt.score(x_test,y_test)
                mss.append(minsamplesplit)
                msl.append(minsampleleaf)
                md.append(maxdepth)
                mln.append(maxleafnodes)
                scores.append(score)
                #print(str(minsamplesplit)+"--->"+str(minsampleleaf)+"----->"+str(maxdepth)+"------>"+str(maxleafnodes)+"------>"+str(score))

# %%
dict={'mss':mss,'msl':msl,'md':md,'mln':mln,'scores':scores}
tn=pd.DataFrame(dict)

# %%
tn
# Out:
#      md  mln  msl  mss    scores
# 0    15   15    2    2  0.902857
# 1    15   16    2    2  0.905238
# 2    15   17    2    2  0.905238
# 3    15   18    2    2  0.905238
# 4    16   15    2    2  0.902857
# 5    16   16    2    2  0.905238
# 6    16   17    2    2  0.905238
# 7    16   18    2    2  0.905238
# 8    17   15    2    2  0.902857
# 9    17   16    2    2  0.905238
# 10   17   17    2    2  0.905238
# 11   17   18    2    2  0.905238
# 12   18   15    2    2  0.902857
# 13   18   16    2    2  0.905238
# 14   18   17    2    2  0.905238
# 15   18   18    2    2  0.905238
# 16   15   15    3    2  0.902857
# 17   15   16    3    2  0.905238
# 18   15   17    3    2  0.905238
# 19   15   18    3    2  0.905238
# 20   16   15    3    2  0.902857
# 21   16   16    3    2  0.905238
# 22   16   17    3    2  0.905238
# 23   16   18    3    2  0.905238
# 24   17   15    3    2  0.902857
# 25   17   16    3    2  0.905238
# 26   17   17    3    2  0.905238
# ...

# %%
dict={'mss':mss,'msl':msl,'md':md,'mln':mln,'scores':scores}
tn=pd.DataFrame(dict)
mask=tn['scores'].max()
tn.loc[tn['scores']==mask,:]
# Out:
#      md  mln  msl  mss    scores
# 1    15   16    2    2  0.905238
# 2    15   17    2    2  0.905238
# 3    15   18    2    2  0.905238
# 5    16   16    2    2  0.905238
# 6    16   17    2    2  0.905238
# 7    16   18    2    2  0.905238
# 9    17   16    2    2  0.905238
# 10   17   17    2    2  0.905238
# 11   17   18    2    2  0.905238
# 13   18   16    2    2  0.905238
# 14   18   17    2    2  0.905238
# 15   18   18    2    2  0.905238
# 17   15   16    3    2  0.905238
# 18   15   17    3    2  0.905238
# 19   15   18    3    2  0.905238
# 21   16   16    3    2  0.905238
# 22   16   17    3    2  0.905238
# 23   16   18    3    2  0.905238
# 25   17   16    3    2  0.905238
# 26   17   17    3    2  0.905238
# 27   17   18    3    2  0.905238
# 29   18   16    3    2  0.905238
# 30   18   17    3    2  0.905238
# 31   18   18    3    2  0.905238
# 33   15   16    4    2  0.905238
# 34   15   17    4    2  0.905238
# 35   15   18    4    2  0.905238
# ...

# %% [markdown]
# Hasil plot tuning dan scores

# %%
plt.scatter(x=tn.md,y=tn.scores)
plt.xscale('linear')
plt.ylabel('Accuracy')
plt.xlabel('Max_depth')
plt.title('Max_depth to accuracy')
plt.show()

# %%
plt.scatter(x=tn.mln,y=tn.scores)
plt.xscale('linear')
plt.ylabel('Accuracy')
plt.xlabel('Max_leaf_nodes')
plt.title('Max_leaf_nodes to accuracy')
plt.show()

# %%
plt.scatter(x=tn.msl,y=tn.scores)
plt.xscale('linear')
plt.ylabel('Accuracy')
plt.xlabel('Min_sample_leaf')
plt.title('Min_sample_leaf to accuracy')
plt.show()

# %%
plt.scatter(x=tn.mss,y=tn.scores)
plt.xscale('linear')
plt.ylabel('Accuracy')
plt.xlabel('Min_sample_split')
plt.title('Min_sample_split to accuracy')
plt.show()
